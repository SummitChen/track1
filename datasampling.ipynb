# %%
import numpy as np
import pandas as pd

# %%
raw = pd.read_csv('data/train.csv')

# %%
raw.head()
# Out:
#    order_detail_id  order_id  order_total_num  order_amount  \
# 0          1000000   1000000              1.0         239.9
# 1          1001530   1001327              2.0         288.0
# 2          1001531   1001327              2.0         288.0
# 3          1001532   1001328              3.0         180.0
# 4          1001533   1001329              1.0         159.9
#
#    order_total_payment  order_total_discount       order_pay_time  \
# 0                 96.9                   0.0  2012-11-01 00:10:56
# 1                 96.9                   0.0  2013-08-31 23:14:42
# 2                 96.9                   0.0  2013-08-31 23:14:42
# 3                 89.7                   0.0  2013-08-31 22:06:35
# 4                 65.9                   0.0  2013-08-31 21:33:36
#
#    order_status  order_count  is_customer_rate  ...  customer_gender  \
# 0             6          1.0               0.0  ...              NaN
# ...

# %%
raw.shape
# Out:
# (2306871, 29)

# %%
samples = raw.sample(frac = .10)

# %%
samples.head()
# Out:
#          order_detail_id  order_id  order_total_num  order_amount  \
# 909161           2056354   1901619              1.0         359.0
# 1048030          2215318   2036964              1.0         239.9
# 1207392          2400994   2195613              1.0         175.9
# 1223280          2419921   2211683              1.0         239.9
# 2160121          3513506   3103799              1.0         239.9
#
#          order_total_payment  order_total_discount       order_pay_time  \
# 909161                 95.95                 95.95  2013-08-10 10:00:10
# 1048030                83.90                  0.00  2012-11-11 13:47:45
# 1207392               132.90                  3.00  2012-11-11 05:49:58
# 1223280                89.90                  0.00  2013-01-18 00:05:00
# 2160121                78.72                 11.18  2013-01-24 00:07:26
#
#          order_status  order_count  is_customer_rate  ...  customer_gender  \
# ...

# %%
samples.shape
# Out:
# (230687, 29)

# %%
samples.to_csv('data/train_samples.csv')
